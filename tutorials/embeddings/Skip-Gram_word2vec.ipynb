# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.
#
# Try what I can write in this mode.
#
# how are you.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %% [markdown]
# 把所有的标点符号变成一个token.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %% [markdown]
# ## TODO
# 1. 把所有的单词的词频算出来.
# 2. 把所有单词的概率算出来.

# %% [markdown]
# ### bug分析
# 题目要求使用int——words来操作, 但是我使用了word, 导致后面的错误

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Your code here
# import math
# from collections import Counter
# from numpy.random import random
# def generate_trainwords(words, threshold=1e-5):
#     # In the paper, they use threshold of value 1e-5
#     c = Counter(set(words))
#     lenth = len(words)
#     for word in words:
#         c[word] += 1
#     words = dict(c)
#     train_words = list()
#     for word in words:
#          if 1 - math.sqrt(threshold / words[word] * lenth) > random():
#             train_words.append(word)
#     return train_words

# %%
train_words[2]
# Out:
# 58

# %% [markdown]
# ### TODO
# if the threshold using like what i do above?

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import choice

# %%
import random

# %%
choice(words[1:10])
# Out:
# 'first'

# %%
words[1]
# Out:
# 'originated'

# %%
words[1:2]
# Out:
# ['originated']

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # in the range of window, randomly choose 5 words from it.
    # words ==> list, idx ==> int
    # Your code here
    R = random.randint(1, window_size)
    start = idx - R if (idx - R) > 0 else 0
    end = idx + R
    return list(set(words[start : idx] + words[idx+1:end+1]))

# %%
get_target(words=words[1:20], idx=10)
# Out:
# ['against', 'radicals', 'class', 'early']

# %% [markdown]
# 使用set了之后, 把重复的单词去掉了, 那么返回的长度都不一样怎么办?
#
# 下面解决了

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %% [markdown]
# ### 他的困难是什么?
# 1. 不能找到一个可以接受任意长度的targets的结构.
# 2. 解决方式: 使用input-target的这种pair的形式来处理数据, 就是把input复制到和targets一样长.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
next(get_batches(words=words[1:30], batch_size=4))
# Out:
# (['originated', 'as', 'as', 'as', 'a', 'a', 'a', 'term', 'term', 'term'],
#  ['as',
#   'a',
#   'originated',
#   'term',
#   'originated',
#   'term',
#   'as',
#   'a',
#   'originated',
#   'as'])

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
tf.__version__
# Out:
# '1.0.0'

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=(None), name='inputs')
    # why there is None for inputs, isn't it be the num of input layer neurons.
    labels = tf.placeholder(dtype=tf.int32, shape=(None, 1), name='labels')

# %% [markdown]
# ### inputs
# The inputs should be the integers rather than a matrix.
#
# what is the shpae of the inputs?
#
# 这里使用一个数字是因为, 后面使用tf.nn.embedding_lookup的ids参数的需要.

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %% [markdown]
# ### translation
# embedding matrix的size是(字典长度*hidden units 数目). 使用int来替代单词, int的数目就是字典的长度.
#
# 1. tf.nn.embedding_lookup
#     使用embedding matrix作为输入
#     返回 embedding matrix的id的那一行的vector.
# 2. 使用200作为hidden的值.
# 3. 创建embedding matrix的variable.
# 4. 使用tf.nn.embedding_lookup得到需要的embedding tensors.
# 5. embedding matrix 使用uniform来初始化 tf.random_uniform

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1, name='embedding_matrix'))
    embed = tf.nn.embedding_lookup(params=embedding, ids=inputs)

# %% [markdown]
# uniform default minval is 0, so it should be set to -1 and maxval to 1.

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %% [markdown]
# ### translation
# 每一个进入网络的数据, 我们使用soft Max来训练, 那就意味着, 每次迭代更新的范围很小, 这样训练网络的效率非常低.
# - 解释: 因为我们的embedding matrix是一个很大的网络, 每一个单词只是里面的一行权重, 所以每次训练的时候, 只是更新其中的几行而已, 需要使用一个更高效的方法来训练, 可以减少运算.
#
# 使用negative sampling来处理soft Max, 让他的结果尽量接近soft Max的真实值.

# %% [markdown]
# ### 问题
# 这个softmax的结构是什么样子的?
# 权重的shape是什么样子的?

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.01))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.4014 0.1131 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.3524 0.0649 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.2825 0.0664 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3074 0.0637 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2481 0.0666 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2036 0.0624 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.1780 0.0685 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1176 0.0648 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9836 0.0678 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.8575 0.0702 sec/batch
# Nearest to united: relations, hope, custer, stretches, cities, gunnery, always, near,
# Nearest to american: concept, chemistry, twenty, did, array, oligosaccharides, victories, hope,
# Nearest to can: thee, gets, tips, nste, hitherto, training, toner, altitude,
# Nearest to with: therefore, savoy, ferries, similarities, namibia, robert, inadequacy, chemnitz,
# Nearest to at: vlaanderen, so, appeared, defined, any, soon, assembl, marshy,
# Nearest to and: rural, contemplative, carry, wwii, prominent, merely, twelve, interpreter,
# Nearest to their: field, manuscript, actually, relatively, exchange, geschichte, payment, remix,
# Nearest to than: not, companies, life, opening, seventh, product, prove, gaining,
# Nearest to award: aegis, attention, widget, proffered, death, announcer, sanctions, isabel,
# Nearest to woman: joseph, buildings, basil, titanic, dirt, bryn, cultural, wound,
# Nearest to orthodox: bid, invaders, along, cosa, band, conjunctions, own, uncle,
# Nearest to report: leadbelly, battles, strychnine, lowest, bavaria, flask, hidden, value,
# Nearest to running: will, dozen, containing, pero, fix, interpolated, add, undergraduates,
# Nearest to writers: turbojet, merger, cido, about, skater, viable, berglin, pun,
# Nearest to additional: cf, helpers, embarking, vol, examination, toni, show, forms,
# Nearest to test: nagarjuna, transgenic, encouraged, use, touring, ivory, messiah, tunnel,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.8695 0.0737 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.7923 0.0670 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7867 0.0690 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7507 0.0711 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.7522 0.0719 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.6957 0.0686 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7052 0.0704 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7115 0.0744 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.6792 0.0716 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.6974 0.0696 sec/batch
# Nearest to united: stretches, custer, relations, spokesman, disparities, austen, gunnery, reserve,
# Nearest to american: oligosaccharides, guitarist, economist, spengler, predominate, associativity, hypopituitarism, poetic,
# Nearest to can: thee, chanced, hitherto, normative, schemes, toner, resurfaced, hartnett,
# Nearest to with: ferries, therefore, savoy, similarities, turnover, yoshida, oracle, tissue,
# Nearest to at: vlaanderen, replete, assembl, dup, peaceful, molecules, hermaphrodite, debating,
# Nearest to and: contemplative, wwii, rural, merely, interpreter, carry, harps, naturally,
# Nearest to their: geschichte, serapion, manuscript, payment, field, switchable, atolls, pitting,
# Nearest to than: governorate, repair, eaten, plume, tuning, sally, agro, principe,
# Nearest to award: aegis, widget, proffered, stabilized, announcer, refugee, guti, englehart,
# Nearest to woman: basil, titanic, landings, bryn, dirt, joseph, buildings, sweeney,
# Nearest to orthodox: cosa, conjunctions, invaders, bid, homosexual, evidences, uncle, landscapes,
# Nearest to report: leadbelly, strychnine, simulation, ineligible, battles, bavaria, emory, flask,
# Nearest to running: interpolated, dozen, pero, fix, emilia, reheating, leffler, squandered,
# Nearest to writers: cido, pun, turbojet, berglin, corbusier, dat, skater, dosage,
# Nearest to additional: helpers, cf, embarking, provably, examination, surveyor, encompass, suits,
# Nearest to test: nagarjuna, transgenic, spiritualism, heaps, encouraged, optimization, reminders, erich,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6664 0.0738 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6527 0.0708 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6749 0.0735 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6511 0.0675 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6097 0.0735 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6165 0.0688 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5997 0.0698 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.6222 0.0712 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.5723 0.0685 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6229 0.0708 sec/batch
# Nearest to united: stretches, custer, relations, cromwell, austen, spokesman, participated, medici,
# Nearest to american: guitarist, economist, spengler, heather, knopf, oligosaccharides, predominate, stockton,
# Nearest to can: chanced, thee, hitherto, debugging, resurfaced, hartnett, schemes, toner,
# Nearest to with: savoy, ferries, yoshida, therefore, turnover, similarities, oracle, strongpoints,
# Nearest to at: vlaanderen, replete, dup, hermaphrodite, debating, assembl, inspirations, peaceful,
# Nearest to and: contemplative, lpg, wwii, marshallese, vests, patriarchal, prominent, sidelines,
# Nearest to their: serapion, manuscript, geschichte, switchable, pitting, payment, atolls, field,
# Nearest to than: governorate, fiat, plume, repair, airframe, principe, tuning, eaten,
# Nearest to award: aegis, proffered, widget, isabel, stabilized, knopf, guti, graduating,
# Nearest to woman: basil, titanic, landings, joseph, bryn, coincides, sweeney, dirt,
# Nearest to orthodox: cosa, conjunctions, homosexual, autonomously, landscapes, bid, evidences, invaders,
# Nearest to report: leadbelly, ineligible, strychnine, simulation, hort, bavaria, pandavas, emory,
# Nearest to running: interpolated, pero, emilia, dozen, reheating, leffler, hominids, squandered,
# Nearest to writers: cido, corbusier, skater, berglin, dat, pun, exoplanet, quatre,
# Nearest to additional: helpers, cf, embarking, dionysian, surveyor, provably, forms, tensors,
# Nearest to test: nagarjuna, transgenic, heaps, spiritualism, hamito, fabrique, optimization, stakeholder,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6150 0.0711 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5672 0.0735 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5817 0.0672 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5339 0.0677 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5640 0.0681 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4907 0.0703 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5684 0.0736 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5756 0.0712 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5374 0.0725 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.4961 0.0686 sec/batch
# Nearest to united: stretches, custer, relations, austen, spokesman, cromwell, infighting, escalator,
# Nearest to american: economist, guitarist, inventor, spengler, duchess, heather, knopf, predominate,
# Nearest to can: chanced, thee, tractatus, debugging, toner, hitherto, definite, intermolecular,
# Nearest to with: savoy, ferries, yoshida, turnover, therefore, oracle, strongpoints, similarities,
# Nearest to at: vlaanderen, replete, dup, inspirations, assembl, gwyneth, hermaphrodite, benedetto,
# Nearest to and: contemplative, wwii, marshallese, patriarchal, lpg, rural, vests, memoirists,
# Nearest to their: serapion, payment, manuscript, switchable, geschichte, pitting, offence, informing,
# Nearest to than: governorate, fiat, principe, unpalatable, plume, agro, airframe, suppressive,
# Nearest to award: aegis, guti, isabel, knopf, graduating, proffered, prolifically, stabilized,
# Nearest to woman: basil, titanic, landings, sweeney, coincides, nahar, bryn, joseph,
# Nearest to orthodox: cosa, conjunctions, homosexual, isthmian, autonomously, isidore, landscapes, invaders,
# Nearest to report: leadbelly, strychnine, ineligible, hort, pandavas, simulation, rabelais, emory,
# Nearest to running: interpolated, pero, emilia, dozen, reheating, hominids, pistol, leffler,
# Nearest to writers: cido, skater, corbusier, berglin, alison, van, bebox, pun,
# Nearest to additional: helpers, cf, dionysian, embarking, provably, tensors, forms, examination,
# Nearest to test: nagarjuna, transgenic, heaps, hamito, spiritualism, fabrique, optimization, ephemerides,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.5032 0.0675 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4919 0.0710 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.4458 0.0742 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4707 0.0772 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4863 0.0739 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4994 0.0699 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.4389 0.0505 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.4332 0.0692 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.3659 0.0707 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.3809 0.0731 sec/batch
# Nearest to united: stretches, custer, relations, austen, gunnery, escalator, disparities, ning,
# Nearest to american: guitarist, inventor, economist, ornithologist, spengler, chemistry, rick, weezer,
# Nearest to can: chanced, thee, lubrication, toner, tractatus, debugging, wiretaps, hitherto,
# Nearest to with: ferries, savoy, yoshida, strongpoints, therefore, oracle, turnover, enlil,
# Nearest to at: vlaanderen, replete, dup, gwyneth, benedetto, shit, inspirations, irvine,
# Nearest to and: marshallese, contemplative, patriarchal, lpg, memoirists, ayn, jackpots, wwii,
# Nearest to their: serapion, switchable, payment, manuscript, pitting, informing, offence, alarming,
# Nearest to than: governorate, fiat, principe, airframe, suppressive, unpalatable, repair, agro,
# Nearest to award: guti, aegis, macbook, prolifically, knopf, graduating, proffered, announcer,
# Nearest to woman: basil, titanic, landings, turboprops, kids, sweeney, cultures, coincides,
# Nearest to orthodox: cosa, conjunctions, homosexual, isthmian, isidore, invaders, landscapes, uncle,
# Nearest to report: leadbelly, ineligible, strychnine, pandavas, hort, rabelais, madly, alcock,
# Nearest to running: interpolated, pero, emilia, pistol, reheating, dozen, unsecured, suckling,
# Nearest to writers: cido, skater, corbusier, berglin, dat, bebox, alison, van,
# Nearest to additional: helpers, dionysian, cf, embarking, tensors, examination, surveyor, provably,
# Nearest to test: nagarjuna, transgenic, heaps, fabrique, spiritualism, hamito, ephemerides, cheshire,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.3489 0.0708 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.3672 0.0736 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.3403 0.0692 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4056 0.0742 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.3853 0.0736 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.3850 0.0688 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3366 0.0741 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.2966 0.0691 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3185 0.0723 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.2793 0.0744 sec/batch
# Nearest to united: stretches, relations, escalator, infighting, custer, gunnery, disparities, austen,
# Nearest to american: guitarist, hypopituitarism, weezer, inventor, chemistry, oligosaccharides, faber, spengler,
# Nearest to can: chanced, lubrication, toner, thee, hitherto, wiretaps, debugging, modulating,
# Nearest to with: ferries, savoy, yoshida, strongpoints, therefore, oracle, turnover, eudoxus,
# Nearest to at: vlaanderen, replete, dup, irvine, gwyneth, shit, so, dixieland,
# Nearest to and: contemplative, marshallese, lpg, patriarchal, alles, memoirists, sidelines, ayn,
# Nearest to their: serapion, payment, manuscript, switchable, pitting, offence, informing, earley,
# Nearest to than: governorate, fiat, suppressive, principe, airframe, agro, unpalatable, repair,
# Nearest to award: aegis, guti, macbook, reuters, prolifically, knopf, laudatory, ungulate,
# Nearest to woman: basil, titanic, turboprops, landings, kids, sweeney, cultures, sowell,
# Nearest to orthodox: cosa, conjunctions, christians, homosexual, isidore, scripture, isthmian, texts,
# Nearest to report: leadbelly, ineligible, strychnine, rabelais, pandavas, alcock, simulation, hort,
# Nearest to running: interpolated, pero, reheating, pistol, emilia, dozen, entourage, unsecured,
# Nearest to writers: cido, corbusier, dat, berglin, skater, scripted, bebox, pun,
# Nearest to additional: helpers, dionysian, cf, embarking, provably, iie, andries, nahin,
# Nearest to test: nagarjuna, transgenic, heaps, fabrique, hamito, reminders, cheshire, spiritualism,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3482 0.0711 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3336 0.0780 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3428 0.0765 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.2627 0.0804 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.2973 0.0752 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.3639 0.0787 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3023 0.0793 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.2800 0.0835 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3232 0.0793 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.2718 0.0834 sec/batch
# Nearest to united: stretches, relations, escalator, gunnery, reserve, infighting, custer, theodosian,
# Nearest to american: inventor, weezer, guitarist, chemistry, spengler, ornithologist, faber, oligosaccharides,
# Nearest to can: thee, lubrication, chanced, toner, hitherto, modulating, irresistible, satavahana,
# Nearest to with: savoy, ferries, yoshida, strongpoints, therefore, turnover, oracle, eudoxus,
# Nearest to at: vlaanderen, replete, dup, irvine, dixieland, gwyneth, so, hyperlink,
# Nearest to and: lpg, patriarchal, marshallese, alles, ayn, contemplative, jackpots, rural,
# Nearest to their: serapion, payment, manuscript, switchable, offence, informing, pitting, trentino,
# Nearest to than: governorate, suppressive, fiat, unpalatable, agro, tuning, principe, airframe,
# Nearest to award: aegis, guti, macbook, reuters, topped, prolifically, ungulate, patton,
# Nearest to woman: basil, titanic, landings, turboprops, kids, sweeney, cultures, karo,
# Nearest to orthodox: cosa, conjunctions, homosexual, isthmian, isidore, christians, scripture, stoicism,
# Nearest to report: leadbelly, ineligible, strychnine, pandavas, alcock, rabelais, hort, overpopulation,
# Nearest to running: interpolated, pero, pistol, reheating, emilia, unsecured, cen, suckling,
# Nearest to writers: cido, corbusier, berglin, dat, bebox, scripted, pun, skater,
# Nearest to additional: helpers, dionysian, cf, embarking, iie, nahin, provably, viridis,
# Nearest to test: nagarjuna, heaps, transgenic, fabrique, hamito, ephemerides, shrunken, cheshire,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2953 0.0792 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.2880 0.0806 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.2463 0.0801 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2791 0.0842 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3225 0.0776 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.2784 0.0811 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3054 0.0790 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.2885 0.0878 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2589 0.0794 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2661 0.0797 sec/batch
# Nearest to united: relations, gunnery, ning, stretches, escalator, infighting, theodosian, reserve,
# Nearest to american: weezer, oligosaccharides, chemistry, hypopituitarism, inventor, predominate, faber, spengler,
# Nearest to can: thee, toner, chanced, lubrication, hitherto, irresistible, modulating, satavahana,
# Nearest to with: savoy, ferries, strongpoints, yoshida, therefore, turnover, oracle, similarities,
# Nearest to at: vlaanderen, replete, dixieland, dup, so, gwyneth, irvine, debating,
# Nearest to and: patriarchal, marshallese, contemplative, alles, lpg, ayn, jackpots, vests,
# Nearest to their: serapion, payment, manuscript, offence, switchable, patagonian, informing, trentino,
# Nearest to than: governorate, suppressive, fiat, unpalatable, agro, principe, airframe, tuning,
# Nearest to award: aegis, topped, macbook, guti, reuters, ungulate, patton, prolifically,
# Nearest to woman: basil, titanic, turboprops, landings, kids, cultures, sowell, karo,
# Nearest to orthodox: cosa, conjunctions, homosexual, isidore, scripture, isthmian, stoicism, christians,
# Nearest to report: leadbelly, ineligible, rabelais, overpopulation, alcock, pandavas, strychnine, nsg,
# Nearest to running: interpolated, pero, pistol, reheating, unsecured, emilia, cen, dozen,
# Nearest to writers: cido, corbusier, scripted, berglin, dat, laozi, peddle, bebox,
# Nearest to additional: helpers, dionysian, cf, nahin, andries, embarking, baccio, iie,
# Nearest to test: nagarjuna, transgenic, heaps, fabrique, hamito, ephemerides, optimization, cheshire,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.2536 0.0780 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2231 0.0810 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.2946 0.0795 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3211 0.0831 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3329 0.0791 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2002 0.0804 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2162 0.0824 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2855 0.0821 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1374 0.0809 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2297 0.0774 sec/batch
# Nearest to united: gunnery, ning, escalator, stretches, relations, hirschfeld, scilly, disparities,
# Nearest to american: weezer, inventor, ornithologist, spengler, shaffer, guitarist, chemistry, economist,
# Nearest to can: lubrication, thee, toner, chanced, modulating, hitherto, irresistible, magma,
# Nearest to with: savoy, strongpoints, yoshida, ferries, therefore, turnover, oracle, similarities,
# Nearest to at: vlaanderen, replete, dixieland, so, dup, debating, hyperlink, shit,
# Nearest to and: marshallese, patriarchal, contemplative, alles, ayn, lpg, jackpots, linares,
# Nearest to their: serapion, payment, manuscript, offence, switchable, patagonian, trentino, characterizing,
# Nearest to than: governorate, suppressive, fiat, principe, unpalatable, agro, product, tuning,
# Nearest to award: aegis, topped, guti, ungulate, macbook, patton, reuters, laudatory,
# Nearest to woman: basil, landings, turboprops, titanic, cultures, sowell, kids, birth,
# Nearest to orthodox: cosa, conjunctions, homosexual, isidore, scripture, evangelical, stoicism, isthmian,
# Nearest to report: leadbelly, ineligible, alcock, rabelais, strychnine, pandavas, nsg, vocational,
# Nearest to running: interpolated, pistol, pero, reheating, emilia, dozen, cen, unsecured,
# Nearest to writers: cido, scripted, dat, bebox, corbusier, laozi, peddle, gypsy,
# Nearest to additional: helpers, dionysian, cf, howto, andries, nahin, viridis, embarking,
# Nearest to test: nagarjuna, transgenic, heaps, fabrique, ephemerides, cheshire, erich, hamito,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2551 0.0837 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2444 0.0773 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2588 0.0337 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1796 0.0793 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1571 0.0825 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1445 0.0815 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1462 0.0815 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1490 0.0803 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1665 0.0789 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1315 0.0811 sec/batch
# Nearest to united: gunnery, ning, escalator, relations, stretches, hirschfeld, theodosian, karlheinz,
# Nearest to american: weezer, oligosaccharides, hypopituitarism, inventor, predominate, thurman, commando, spengler,
# Nearest to can: lubrication, thee, toner, chanced, hitherto, irresistible, magma, modulating,
# Nearest to with: savoy, ferries, strongpoints, yoshida, therefore, turnover, oracle, faris,
# Nearest to at: vlaanderen, replete, dixieland, dup, so, hyperlink, shit, handedly,
# Nearest to and: marshallese, contemplative, schreiber, jackpots, voucher, alles, patriarchal, lpg,
# Nearest to their: manuscript, serapion, payment, offence, characterizing, patagonian, field, earley,
# Nearest to than: governorate, suppressive, fiat, principe, unpalatable, agro, mingled, chuvash,
# Nearest to award: topped, aegis, ungulate, guti, laudatory, macbook, multisyllabic, reuters,
# Nearest to woman: basil, landings, sowell, titanic, cultures, birth, turboprops, kids,
# Nearest to orthodox: cosa, conjunctions, homosexual, isidore, evangelical, stoicism, pali, scripture,
# Nearest to report: leadbelly, ineligible, rabelais, alcock, nsg, strychnine, pandavas, overpopulation,
# Nearest to running: interpolated, pistol, reheating, pero, emilia, dozen, suckling, cen,
# Nearest to writers: cido, dat, scripted, bebox, corbusier, gypsy, laozi, berglin,
# Nearest to additional: helpers, dionysian, cf, howto, viridis, nahin, iie, baccio,
# Nearest to test: nagarjuna, transgenic, heaps, ephemerides, erich, fabrique, cheshire, condiments,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2180 0.0828 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1704 0.0834 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1661 0.0813 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1037 0.0813 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1217 0.0784 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1412 0.0829 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1299 0.0761 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1372 0.0790 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1321 0.0779 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1510 0.0755 sec/batch
# Nearest to united: gunnery, escalator, hirschfeld, relations, ning, scilly, stretches, karlheinz,
# Nearest to american: weezer, oligosaccharides, hypopituitarism, predominate, commando, tromelin, lumpy, presse,
# Nearest to can: lubrication, thee, hitherto, irresistible, modulating, toner, chanced, gush,
# Nearest to with: savoy, yoshida, ferries, strongpoints, therefore, similarities, oracle, turnover,
# Nearest to at: replete, vlaanderen, dixieland, dup, so, shit, handedly, hyperlink,
# Nearest to and: marshallese, alles, contemplative, patriarchal, vests, jackpots, voucher, rural,
# Nearest to their: payment, manuscript, serapion, offence, patagonian, characterizing, nonkinetochore, vietnamese,
# Nearest to than: governorate, suppressive, fiat, mingled, principe, fundamentalist, tuning, agro,
# Nearest to award: aegis, topped, ungulate, laudatory, multisyllabic, macbook, reuters, guti,
# Nearest to woman: basil, sowell, landings, asher, titanic, birth, kids, turboprops,
# Nearest to orthodox: cosa, conjunctions, isidore, homosexual, evangelical, stoicism, pali, scripture,
# Nearest to report: leadbelly, ineligible, alcock, nsg, simulation, rabelais, strychnine, cambodian,
# Nearest to running: pistol, interpolated, reheating, pero, runeword, emilia, entourage, scrapped,
# Nearest to writers: cido, scripted, dat, laozi, corbusier, peddle, gogol, gypsy,
# Nearest to additional: helpers, dionysian, cf, howto, viridis, baccio, nahin, embarking,
# Nearest to test: nagarjuna, heaps, transgenic, erich, ephemerides, fabrique, condiments, reminders,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1440 0.0829 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1911 0.0835 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1261 0.0774 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1224 0.0802 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1344 0.0774 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1425 0.0779 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1619 0.0812 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1064 0.0788 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0819 0.0795 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1541 0.0757 sec/batch
# Nearest to united: ning, hirschfeld, gunnery, karlheinz, relations, scilly, escalator, stretches,
# Nearest to american: weezer, predominate, commando, inventor, pavlov, economist, tromelin, ornithologist,
# Nearest to can: thee, lubrication, hitherto, modulating, irresistible, toner, gush, chanced,
# Nearest to with: savoy, strongpoints, ferries, yoshida, therefore, faris, turnover, convulsions,
# Nearest to at: dixieland, replete, vlaanderen, debating, so, dup, hermaphrodite, handedly,
# Nearest to and: marshallese, patriarchal, alles, voucher, jackpots, vests, contemplative, rural,
# Nearest to their: manuscript, payment, serapion, offence, characterizing, nonkinetochore, field, patagonian,
# Nearest to than: suppressive, governorate, fundamentalist, planar, fiat, principe, unpalatable, product,
# Nearest to award: aegis, topped, ungulate, laudatory, nominated, macbook, multisyllabic, awards,
# Nearest to woman: basil, titanic, sowell, landings, asher, birth, expectancy, myst,
# Nearest to orthodox: cosa, isidore, conjunctions, evangelical, homosexual, pali, dogmatic, stoicism,
# Nearest to report: leadbelly, ineligible, alcock, simulation, nsg, overpopulation, rabelais, patrick,
# Nearest to running: interpolated, pistol, pero, reheating, entourage, dozen, emilia, runeword,
# Nearest to writers: cido, dat, laozi, scripted, peddle, gogol, gypsy, corbusier,
# Nearest to additional: helpers, dionysian, cf, howto, viridis, embarking, airplay, bamileke,
# Nearest to test: nagarjuna, heaps, transgenic, erich, ephemerides, fabrique, lond, condiments,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1600 0.0751 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1267 0.0795 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1328 0.0784 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1461 0.0817 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1146 0.0771 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1175 0.0755 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1107 0.0766 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0942 0.0801 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1861 0.0758 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2007 0.0760 sec/batch
# Nearest to united: hirschfeld, ning, karlheinz, gunnery, relations, escalator, scilly, stendhal,
# Nearest to american: weezer, predominate, economist, tromelin, commando, inventor, oligosaccharides, hypopituitarism,
# Nearest to can: thee, lubrication, hitherto, irresistible, modulating, toner, gush, chanced,
# Nearest to with: savoy, strongpoints, yoshida, ferries, therefore, faris, convulsions, similarities,
# Nearest to at: dixieland, replete, vlaanderen, debating, so, cassavetes, handedly, dup,
# Nearest to and: marshallese, patriarchal, schreiber, contemplative, unmixed, sikh, voucher, jackpots,
# Nearest to their: manuscript, serapion, payment, offence, characterizing, petitioned, patagonian, trentino,
# Nearest to than: governorate, suppressive, principe, fundamentalist, zmir, chuvash, indiscriminate, fiat,
# Nearest to award: aegis, ungulate, topped, nominated, laudatory, awards, macbook, multisyllabic,
# Nearest to woman: basil, sowell, landings, asher, titanic, expectancy, kids, birth,
# Nearest to orthodox: cosa, isidore, conjunctions, evangelical, homosexual, pali, apostasy, dogmatic,
# Nearest to report: leadbelly, ineligible, alcock, nsg, overpopulation, simulation, pandavas, rabelais,
# Nearest to running: pero, pistol, reheating, interpolated, suckling, entourage, emilia, dozen,
# Nearest to writers: cido, dat, journalists, peddle, gogol, scripted, laozi, gypsy,
# Nearest to additional: helpers, dionysian, cf, viridis, howto, nahin, baccio, bamileke,
# Nearest to test: nagarjuna, heaps, transgenic, erich, lond, ephemerides, ipsec, optimization,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1783 0.0816 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1051 0.0815 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1068 0.0763 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1072 0.0802 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0069 0.0787 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1005 0.0778 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1312 0.0771 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1000 0.0796 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1561 0.0184 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0723 0.0795 sec/batch
# Nearest to united: ning, karlheinz, hirschfeld, relations, gunnery, escalator, stretches, scilly,
# Nearest to american: predominate, weezer, commando, economist, tromelin, pavlov, peale, spengler,
# Nearest to can: lubrication, thee, modulating, hitherto, irresistible, toner, gush, chanced,
# Nearest to with: savoy, strongpoints, ferries, yoshida, therefore, faris, convulsions, turnover,
# Nearest to at: dixieland, replete, so, vlaanderen, debating, dup, shit, cassavetes,
# Nearest to and: marshallese, voucher, unmixed, jackpots, schreiber, patriarchal, ringway, sikh,
# Nearest to their: manuscript, serapion, payment, characterizing, patagonian, nonkinetochore, offence, field,
# Nearest to than: governorate, suppressive, fundamentalist, principe, chuvash, indiscriminate, planar, fiat,
# Nearest to award: ungulate, aegis, awards, topped, nominated, laudatory, multisyllabic, guti,
# Nearest to woman: basil, sowell, landings, birth, asher, expectancy, titanic, male,
# Nearest to orthodox: cosa, isidore, conjunctions, homosexual, evangelical, pali, dogmatic, apostasy,
# Nearest to report: leadbelly, ineligible, alcock, overpopulation, simulation, nsg, cambodian, patrick,
# Nearest to running: pistol, reheating, pero, interpolated, suckling, hominids, entourage, will,
# Nearest to writers: cido, journalists, dat, gogol, laozi, peddle, scripted, corbusier,
# Nearest to additional: helpers, cf, dionysian, howto, nahin, installation, bamileke, viridis,
# Nearest to test: nagarjuna, erich, heaps, transgenic, ephemerides, lond, condiments, ipsec,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0745 0.0801 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0500 0.0796 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0648 0.0811 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0515 0.0743 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0471 0.0840 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0156 0.0788 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0786 0.0738 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0663 0.0802 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1066 0.0714 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0315 0.0770 sec/batch
# Nearest to united: relations, ning, karlheinz, stretches, hirschfeld, gunnery, escalator, scilly,
# Nearest to american: predominate, commando, weezer, tromelin, oligosaccharides, hypopituitarism, inventor, shaffer,
# Nearest to can: lubrication, thee, modulating, magma, gush, hitherto, irresistible, satavahana,
# Nearest to with: savoy, strongpoints, ferries, yoshida, therefore, faris, turnover, convulsions,
# Nearest to at: dixieland, replete, so, debating, vlaanderen, dup, handedly, cassavetes,
# Nearest to and: marshallese, voucher, unmixed, jackpots, rural, schreiber, ringway, alles,
# Nearest to their: manuscript, serapion, patagonian, payment, characterizing, field, nonkinetochore, offence,
# Nearest to than: suppressive, governorate, fundamentalist, principe, indiscriminate, planar, chuvash, sally,
# Nearest to award: topped, awards, ungulate, nominated, aegis, multisyllabic, recipients, laudatory,
# Nearest to woman: basil, sowell, asher, birth, landings, expectancy, male, attends,
# Nearest to orthodox: cosa, isidore, evangelical, conjunctions, homosexual, apostasy, pali, dogmatic,
# Nearest to report: leadbelly, ineligible, alcock, hidden, overpopulation, patrick, downloadable, simulation,
# Nearest to running: reheating, pero, pistol, interpolated, entourage, iditarod, hominids, suckling,
# Nearest to writers: cido, journalists, gogol, dat, laozi, corbusier, bourdon, quine,
# Nearest to additional: helpers, cf, dionysian, howto, nahin, waiver, viridis, bamileke,
# Nearest to test: erich, nagarjuna, heaps, transgenic, ephemerides, florida, cheshire, condiments,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0053 0.0798 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0317 0.0784 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0030 0.0783 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0572 0.0735 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0647 0.0810 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0357 0.0763 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0419 0.0752 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0672 0.0758 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0578 0.0739 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0533 0.0796 sec/batch
# Nearest to united: karlheinz, relations, ning, hirschfeld, scilly, stretches, gunnery, escalator,
# Nearest to american: predominate, weezer, commando, tromelin, oligosaccharides, economist, presse, shaffer,
# Nearest to can: thee, lubrication, modulating, satavahana, hitherto, magma, gush, irresistible,
# Nearest to with: savoy, strongpoints, yoshida, therefore, ferries, faris, turnover, oracle,
# Nearest to at: dixieland, replete, so, debating, dup, vlaanderen, unconfirmed, hermaphrodite,
# Nearest to and: marshallese, unmixed, voucher, rural, jackpots, alles, ringway, schreiber,
# Nearest to their: manuscript, serapion, nonkinetochore, payment, characterizing, patagonian, field, offence,
# Nearest to than: suppressive, governorate, fundamentalist, planar, sally, higher, chuvash, degenerate,
# Nearest to award: awards, topped, ungulate, nominated, aegis, recipients, multisyllabic, laudatory,
# Nearest to woman: basil, sowell, asher, landings, birth, expectancy, reaped, male,
# Nearest to orthodox: cosa, isidore, evangelical, conjunctions, homosexual, pali, dogmatic, indwelling,
# Nearest to report: ineligible, leadbelly, overpopulation, patrick, alcock, downloadable, cambodian, tenders,
# Nearest to running: reheating, pero, pistol, interpolated, entourage, suckling, hominids, runeword,
# Nearest to writers: cido, journalists, gogol, dat, corbusier, laozi, bourdon, peddle,
# Nearest to additional: helpers, cf, howto, dionysian, nahin, waiver, bamileke, viridis,
# Nearest to test: heaps, erich, nagarjuna, transgenic, ephemerides, condiments, ipsec, florida,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0279 0.0834 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0420 0.0749 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0542 0.0759 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0324 0.0778 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0667 0.0731 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0654 0.0639 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0671 0.0708 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0469 0.0764 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0755 0.0757 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0430 0.0733 sec/batch
# Nearest to united: karlheinz, relations, ning, hirschfeld, scilly, gunnery, escalator, blockbuster,
# Nearest to american: predominate, weezer, commando, oligosaccharides, pavlov, economist, presse, tromelin,
# Nearest to can: thee, lubrication, modulating, satavahana, hitherto, irresistible, gush, debates,
# Nearest to with: savoy, strongpoints, yoshida, ferries, faris, therefore, pronunciation, convulsions,
# Nearest to at: dixieland, replete, debating, so, vlaanderen, unconfirmed, dup, hermaphrodite,
# Nearest to and: marshallese, unmixed, jackpots, schreiber, rural, voucher, sikh, ringway,
# Nearest to their: manuscript, serapion, payment, nonkinetochore, patagonian, augmentations, geschichte, characterizing,
# Nearest to than: governorate, suppressive, fundamentalist, planar, higher, zmir, indiscriminate, chuvash,
# Nearest to award: awards, topped, ungulate, nominated, aegis, recipients, multisyllabic, wmap,
# Nearest to woman: basil, asher, sowell, expectancy, reaped, birth, landings, attends,
# Nearest to orthodox: cosa, isidore, evangelical, homosexual, conjunctions, dogmatic, pali, indwelling,
# Nearest to report: ineligible, leadbelly, downloadable, alcock, patrick, overpopulation, hidden, simulation,
# Nearest to running: pero, reheating, interpolated, pistol, entourage, hominids, ovation, suckling,
# Nearest to writers: cido, journalists, gogol, dat, corbusier, laozi, bourdon, peddle,
# Nearest to additional: helpers, cf, waiver, dionysian, nahin, bamileke, howto, sands,
# Nearest to test: heaps, erich, nagarjuna, transgenic, ephemerides, condiments, florida, ipsec,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0640 0.0844 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0261 0.0840 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0254 0.0759 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0802 0.0819 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0911 0.0768 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1309 0.0824 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1368 0.0768 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0335 0.0797 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0294 0.0794 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0342 0.0764 sec/batch
# Nearest to united: karlheinz, ning, relations, gunnery, hirschfeld, nominees, oss, blockbuster,
# Nearest to american: predominate, weezer, commando, tromelin, oligosaccharides, economist, shaffer, concept,
# Nearest to can: thee, lubrication, modulating, satavahana, irresistible, magma, gush, shattuck,
# Nearest to with: savoy, strongpoints, yoshida, ferries, convulsions, marijuana, turnover, therefore,
# Nearest to at: dixieland, so, replete, debating, unconfirmed, cassavetes, vlaanderen, dup,
# Nearest to and: marshallese, unmixed, rural, jackpots, voucher, ringway, schreiber, sikh,
# Nearest to their: manuscript, serapion, payment, nonkinetochore, characterizing, offence, patagonian, augmentations,
# Nearest to than: governorate, suppressive, fundamentalist, higher, planar, indiscriminate, chuvash, zmir,
# Nearest to award: awards, ungulate, topped, nominated, recipients, aegis, wmap, short,
# Nearest to woman: basil, expectancy, sowell, landings, asher, birth, male, reaped,
# Nearest to orthodox: cosa, isidore, homosexual, evangelical, conjunctions, pali, indwelling, dogmatic,
# Nearest to report: ineligible, downloadable, leadbelly, patrick, alcock, hidden, overpopulation, healthier,
# Nearest to running: pero, reheating, pistol, interpolated, hominids, ovation, entourage, suckling,
# Nearest to writers: cido, journalists, gogol, dat, corbusier, bourdon, quine, peddle,
# Nearest to additional: helpers, cf, waiver, howto, bamileke, nahin, dionysian, installation,
# Nearest to test: erich, heaps, nagarjuna, ephemerides, transgenic, condiments, lond, ipsec,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9532 0.0756 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0105 0.0781 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0449 0.0776 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0613 0.0798 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0920 0.0781 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0169 0.0724 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0137 0.0803 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9686 0.0795 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0117 0.0800 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9626 0.0784 sec/batch
# Nearest to united: karlheinz, relations, ning, gunnery, blockbuster, hirschfeld, nominees, censors,
# Nearest to american: predominate, commando, economist, weezer, inventor, tromelin, oligosaccharides, lehrer,
# Nearest to can: thee, lubrication, satavahana, modulating, irresistible, hitherto, bharatiya, magma,
# Nearest to with: savoy, strongpoints, ferries, yoshida, convulsions, therefore, faris, turnover,
# Nearest to at: so, dixieland, replete, debating, vlaanderen, unconfirmed, eleonora, cassavetes,
# Nearest to and: marshallese, jackpots, voucher, unmixed, schreiber, rural, memoirists, sikh,
# Nearest to their: manuscript, nonkinetochore, serapion, patagonian, characterizing, vietnamese, payment, augmentations,
# Nearest to than: governorate, suppressive, higher, fundamentalist, planar, pests, chuvash, sally,
# Nearest to award: awards, ungulate, nominated, topped, recipients, short, lifetime, awarded,
# Nearest to woman: asher, expectancy, basil, landings, sowell, male, birth, reaped,
# Nearest to orthodox: cosa, isidore, evangelical, homosexual, conjunctions, pali, indwelling, dogmatic,
# Nearest to report: downloadable, ineligible, patrick, leadbelly, alcock, overpopulation, hidden, beasley,
# Nearest to running: reheating, pero, iditarod, pistol, interpolated, ovation, entourage, hominids,
# Nearest to writers: cido, journalists, gogol, corbusier, dat, bourdon, poe, peddle,
# Nearest to additional: helpers, nahin, cf, howto, waiver, dionysian, bamileke, installation,
# Nearest to test: erich, ephemerides, heaps, nagarjuna, florida, transgenic, condiments, cheshire,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0061 0.0823 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9464 0.0701 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9844 0.0642 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0180 0.0718 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0206 0.0684 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0127 0.0686 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9130 0.0685 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9606 0.0712 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9455 0.0772 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9757 0.0750 sec/batch
# Nearest to united: karlheinz, relations, ning, oss, nominees, blockbuster, gunnery, hirschfeld,
# Nearest to american: predominate, commando, oligosaccharides, concept, tromelin, bm, duce, weezer,
# Nearest to can: thee, lubrication, modulating, satavahana, hitherto, magma, irresistible, bharatiya,
# Nearest to with: savoy, yoshida, strongpoints, faris, marijuana, ferries, turnover, therefore,
# Nearest to at: so, replete, dixieland, debating, dup, vlaanderen, spokeswoman, unconfirmed,
# Nearest to and: marshallese, unmixed, voucher, rural, jackpots, ringway, sikh, memoirists,
# Nearest to their: manuscript, nonkinetochore, serapion, payment, patagonian, characterizing, vietnamese, augmentations,
# Nearest to than: suppressive, higher, governorate, fundamentalist, sally, planar, indiscriminate, pests,
# Nearest to award: awards, nominated, ungulate, topped, recipients, wmap, awarded, lifetime,
# Nearest to woman: basil, asher, expectancy, sowell, male, reaped, lawfully, attends,
# Nearest to orthodox: cosa, isidore, evangelical, homosexual, pali, conjunctions, dogmatic, indwelling,
# Nearest to report: downloadable, ineligible, overpopulation, leadbelly, patrick, alcock, healthier, hidden,
# Nearest to running: reheating, pero, iditarod, hominids, interpolated, suckling, pistol, ovation,
# Nearest to writers: journalists, cido, gogol, corbusier, dat, bourdon, poe, laozi,
# Nearest to additional: helpers, cf, nahin, waiver, howto, bamileke, dionysian, bottomed,
# Nearest to test: erich, ephemerides, heaps, transgenic, nagarjuna, condiments, florida, cheshire,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0052 0.0756 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0077 0.0763 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9609 0.0791 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0137 0.0793 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0419 0.0781 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9430 0.0756 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0022 0.0789 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9681 0.0725 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9697 0.0791 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0230 0.0812 sec/batch
# Nearest to united: karlheinz, ning, relations, nominees, blockbuster, hirschfeld, oss, gunnery,
# Nearest to american: predominate, commando, weezer, economist, oligosaccharides, tromelin, lehrer, leiter,
# Nearest to can: thee, lubrication, satavahana, modulating, hitherto, gush, bharatiya, counseling,
# Nearest to with: savoy, yoshida, strongpoints, ferries, therefore, faris, turnover, marijuana,
# Nearest to at: so, dixieland, replete, debating, spokeswoman, dismembered, eleonora, reprinting,
# Nearest to and: voucher, unmixed, jackpots, marshallese, rural, ringway, memoirists, schreiber,
# Nearest to their: manuscript, nonkinetochore, serapion, characterizing, payment, augmentations, restated, dismount,
# Nearest to than: higher, suppressive, fundamentalist, sally, governorate, planar, indiscriminate, ivanov,
# Nearest to award: awards, nominated, topped, recipients, ungulate, awarded, short, detours,
# Nearest to woman: asher, reaped, basil, expectancy, sowell, lawfully, attends, landings,
# Nearest to orthodox: cosa, isidore, evangelical, dogmatic, homosexual, pali, indwelling, christians,
# Nearest to report: downloadable, overpopulation, ineligible, leadbelly, alcock, patrick, telling, healthier,
# Nearest to running: reheating, pero, iditarod, hominids, ovation, suckling, jodi, interpolated,
# Nearest to writers: journalists, cido, gogol, dat, poe, corbusier, bourdon, laozi,
# Nearest to additional: helpers, nahin, waiver, cf, howto, bamileke, dionysian, denominations,
# Nearest to test: erich, heaps, nagarjuna, transgenic, ephemerides, florida, condiments, ipsec,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0105 0.0808 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9651 0.0841 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9802 0.0777 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0082 0.0825 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9925 0.0748 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0295 0.0802 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9729 0.0841 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9673 0.0735 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9716 0.0792 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0325 0.0764 sec/batch
# ...
# Nearest to woman: gender, expectancy, attends, tiptree, lawfully, birth, dirt, reaped,
# Nearest to orthodox: isidore, cosa, parties, dogmatic, ques, christians, orthodoxy, pali,
# Nearest to report: downloadable, telling, spark, overpopulation, tenders, luke, tingling, healthier,
# Nearest to running: hominids, reheating, jodi, upset, pero, iditarod, suckling, solanas,
# Nearest to writers: journalists, essayists, novelists, gogol, fiction, corbusier, poe, prophetical,
# Nearest to additional: introduction, nahin, helpers, prominently, alioth, impassioned, denominations, waiver,
# Nearest to test: florida, erich, ephemerides, transgenic, lyn, nagarjuna, closed, condiments,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8163 0.0665 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8841 0.0688 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8820 0.0686 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8714 0.0704 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8944 0.0675 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8898 0.0676 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8639 0.0691 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8556 0.0678 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8847 0.0647 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8692 0.0680 sec/batch
# Nearest to united: nominees, metasyntactic, ning, karlheinz, relations, theodosian, brookside, kingdom,
# Nearest to american: predominate, commando, gemara, lcs, crokinole, supposes, weezer, ceeac,
# Nearest to can: thee, redstone, counseling, lubrication, satavahana, bharatiya, lawyers, tossed,
# Nearest to with: savoy, by, marijuana, disbanding, pharyngealized, four, hand, lifo,
# Nearest to at: so, debating, skiego, confirm, eleonora, dixieland, replete, dismembered,
# Nearest to and: a, such, voucher, departments, shared, patched, rural, unmixed,
# Nearest to their: were, only, manuscript, than, stop, groups, serapion, augmentations,
# Nearest to than: higher, less, suppressive, their, sally, inflectional, planar, much,
# Nearest to award: awards, nominated, awarded, terrence, short, recipients, topped, ungulate,
# Nearest to woman: gender, expectancy, tiptree, attends, lawfully, dirt, birth, asher,
# Nearest to orthodox: isidore, cosa, dogmatic, parties, ques, orthodoxy, christians, pali,
# Nearest to report: downloadable, spark, telling, overpopulation, tenders, luke, joanie, tingling,
# Nearest to running: hominids, reheating, jodi, pero, upset, suckling, dated, iditarod,
# Nearest to writers: journalists, essayists, novelists, poe, fiction, gogol, corbusier, prophetical,
# Nearest to additional: nahin, introduction, prominently, helpers, alioth, payments, waiver, denominations,
# Nearest to test: florida, erich, closed, nagarjuna, lond, sydney, tests, cheshire,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8789 0.0695 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8721 0.0661 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8575 0.0670 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8526 0.0629 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9113 0.0726 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8539 0.0652 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.0043 0.0678 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9101 0.0678 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9460 0.0696 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8171 0.0717 sec/batch
# Nearest to united: nominees, metasyntactic, utah, navigation, ning, theodosian, relations, pharmacokinetics,
# Nearest to american: predominate, commando, weezer, lcs, parton, ku, ramat, gemara,
# Nearest to can: thee, lubrication, redstone, counseling, satavahana, tossed, bharatiya, lawyers,
# Nearest to with: savoy, marijuana, lifo, disbanding, convulsions, by, hand, four,
# Nearest to at: debating, so, skiego, confirm, eleonora, dixieland, chateau, remained,
# Nearest to and: a, such, suspected, rural, voucher, by, shared, departments,
# Nearest to their: only, were, than, manuscript, stop, groups, vietnamese, golfers,
# Nearest to than: higher, less, suppressive, their, inflectional, underlined, sally, governorate,
# Nearest to award: awards, nominated, awarded, terrence, recipients, short, ungulate, topped,
# Nearest to woman: gender, expectancy, tiptree, attends, birth, lawfully, asher, dirt,
# Nearest to orthodox: isidore, cosa, parties, dogmatic, ques, orthodoxy, pali, transnistria,
# Nearest to report: downloadable, telling, spark, tenders, overpopulation, concluded, suspects, luke,
# Nearest to running: hominids, reheating, jodi, pero, upset, suckling, iditarod, solanas,
# Nearest to writers: journalists, essayists, novelists, poe, fiction, gogol, corbusier, quine,
# Nearest to additional: nahin, introduction, helpers, prominently, alioth, denominations, sayyed, sands,
# Nearest to test: florida, erich, tests, closed, lond, lyn, cheshire, nagarjuna,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7838 0.0674 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8639 0.0738 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8236 0.0630 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8852 0.0654 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8852 0.0731 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8901 0.0710 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8728 0.0432 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8425 0.0686 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8657 0.0648 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8640 0.0739 sec/batch
# Nearest to united: navigation, nominees, utah, metasyntactic, theodosian, brookside, ning, kingdom,
# Nearest to american: predominate, commando, lcs, inventor, either, weezer, singer, gemara,
# Nearest to can: thee, lubrication, satavahana, redstone, lawyers, tossed, counseling, bharatiya,
# Nearest to with: savoy, disbanding, hand, convulsions, lifo, by, marijuana, who,
# Nearest to at: so, debating, skiego, eleonora, chateau, confirm, was, remained,
# Nearest to and: a, such, suspected, by, voucher, patched, unwitting, the,
# Nearest to their: only, were, than, stop, manuscript, anacondas, vietnamese, groups,
# Nearest to than: higher, less, suppressive, their, much, inflectional, not, sally,
# Nearest to award: awards, nominated, awarded, terrence, short, recipients, ungulate, topped,
# Nearest to woman: gender, attends, expectancy, tiptree, lawfully, birth, dirt, feminist,
# Nearest to orthodox: isidore, cosa, parties, dogmatic, ques, pali, transnistria, orthodoxy,
# Nearest to report: downloadable, telling, overpopulation, spark, tenders, healthier, luke, tingling,
# Nearest to running: hominids, reheating, upset, jodi, pero, iditarod, suckling, marat,
# Nearest to writers: journalists, essayists, novelists, poe, fiction, gogol, prophetical, corbusier,
# Nearest to additional: nahin, introduction, prominently, helpers, alioth, sands, mccormick, payments,
# Nearest to test: florida, erich, tests, guinevere, closed, cheshire, ephemerides, kathryn,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8343 0.0660 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8534 0.0738 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8477 0.0658 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8265 0.0692 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8731 0.0634 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8576 0.0757 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8847 0.0639 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7980 0.0722 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8352 0.0680 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8368 0.0708 sec/batch
# Nearest to united: navigation, kingdom, utah, nominees, brookside, theodosian, metasyntactic, ning,
# Nearest to american: predominate, either, commando, lcs, gemara, crokinole, supposes, weezer,
# Nearest to can: thee, lawyers, lubrication, counseling, ingest, satavahana, tossed, redstone,
# Nearest to with: lifo, four, savoy, by, marijuana, ahead, disbanding, spilling,
# Nearest to at: so, debating, skiego, confirm, remained, ensures, eleonora, amherst,
# Nearest to and: a, such, voucher, suspected, by, departments, of, the,
# Nearest to their: only, were, than, stop, seminaries, anacondas, vietnamese, of,
# Nearest to than: higher, less, suppressive, their, sally, much, inflectional, not,
# Nearest to award: awards, nominated, awarded, terrence, recipients, ungulate, short, topped,
# Nearest to woman: gender, birth, tiptree, attends, lawfully, expectancy, feminist, asher,
# Nearest to orthodox: isidore, cosa, dogmatic, ques, parties, pali, orthodoxy, transnistria,
# Nearest to report: downloadable, telling, spark, overpopulation, tenders, healthier, luke, tingling,
# Nearest to running: hominids, reheating, upset, iditarod, jodi, pero, suckling, replicates,
# Nearest to writers: journalists, essayists, novelists, fiction, gogol, poe, quine, cido,
# Nearest to additional: introduction, nahin, prominently, helpers, sayyed, alioth, payments, mccormick,
# Nearest to test: florida, erich, tests, cheshire, closed, guinevere, lyn, lond,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8020 0.0730 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8529 0.0648 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8530 0.0710 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8174 0.0649 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8273 0.0724 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8927 0.0666 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8640 0.0707 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8543 0.0682 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8510 0.0671 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8621 0.0631 sec/batch
# Nearest to united: kingdom, nominees, utah, brookside, theodosian, metasyntactic, navigation, pharmacokinetics,
# Nearest to american: predominate, either, commando, lcs, crokinole, gemara, weezer, parton,
# Nearest to can: thee, counseling, satavahana, redstone, lawyers, ingest, tossed, lubrication,
# Nearest to with: lifo, by, disbanding, savoy, marijuana, canes, ahead, four,
# Nearest to at: so, debating, skiego, chateau, emory, eleonora, dixieland, ensures,
# Nearest to and: a, such, by, the, departments, of, patched, is,
# Nearest to their: only, were, than, stop, strongly, anacondas, manuscript, vietnamese,
# Nearest to than: higher, less, suppressive, much, their, not, inflectional, underlined,
# Nearest to award: awards, nominated, terrence, awarded, recipients, ungulate, short, topped,
# Nearest to woman: gender, birth, attends, tiptree, expectancy, dirt, lawfully, asher,
# Nearest to orthodox: isidore, cosa, dogmatic, parties, orthodoxy, ques, christians, pali,
# Nearest to report: downloadable, telling, spark, overpopulation, tenders, luke, concluded, tingling,
# Nearest to running: hominids, reheating, upset, jodi, marat, dated, suckling, iditarod,
# Nearest to writers: journalists, essayists, novelists, fiction, gogol, poe, quine, prophetical,
# Nearest to additional: introduction, prominently, nahin, helpers, waiver, alioth, sayyed, mccormick,
# Nearest to test: florida, tests, erich, lyn, closed, kathryn, lond, ipsec,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8898 0.0715 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8958 0.0739 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8370 0.0691 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8709 0.0735 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8683 0.0634 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8649 0.0713 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8477 0.0636 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8805 0.0653 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8160 0.0676 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8458 0.0639 sec/batch
# Nearest to united: kingdom, nominees, theodosian, utah, navigation, states, brookside, relations,
# Nearest to american: predominate, either, gemara, lcs, commando, mixed, crokinole, supposes,
# Nearest to can: thee, counseling, tossed, satavahana, lawyers, redstone, ingest, debates,
# Nearest to with: lifo, by, savoy, four, pharyngealized, all, disbanding, essentially,
# Nearest to at: so, debating, skiego, eleonora, confirm, remained, ensures, on,
# Nearest to and: a, such, the, of, by, shared, departments, is,
# Nearest to their: only, were, than, groups, stop, seminaries, golfers, leave,
# Nearest to than: less, higher, much, suppressive, their, more, not, governorate,
# Nearest to award: awards, nominated, awarded, terrence, short, ungulate, recipients, wmap,
# Nearest to woman: gender, expectancy, tiptree, birth, attends, lawfully, dirt, feminist,
# Nearest to orthodox: isidore, cosa, parties, dogmatic, orthodoxy, ques, christians, pali,
# Nearest to report: downloadable, telling, spark, overpopulation, luke, tenders, concluded, suspects,
# Nearest to running: hominids, reheating, upset, pero, suckling, jodi, dated, iditarod,
# Nearest to writers: journalists, essayists, novelists, fiction, gogol, poe, corbusier, crichton,
# Nearest to additional: introduction, nahin, prominently, helpers, mccormick, alioth, saxophonist, waiver,
# Nearest to test: florida, tests, erich, lyn, closed, ipsec, lond, ethical,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8652 0.0708 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8246 0.0665 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9363 0.0703 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9438 0.0671 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9090 0.0711 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8676 0.0719 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7798 0.0659 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8699 0.0705 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7352 0.0671 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.9024 0.0706 sec/batch
# Nearest to united: nominees, utah, kingdom, navigation, theodosian, brookside, metasyntactic, states,
# Nearest to american: predominate, commando, lcs, shaffer, crokinole, ku, either, buson,
# Nearest to can: counseling, thee, lawyers, tossed, redstone, ingest, lubrication, designate,
# Nearest to with: lifo, disbanding, marijuana, savoy, essentially, who, ahead, spilling,
# Nearest to at: so, debating, skiego, chateau, confirm, preview, comparatively, emory,
# Nearest to and: a, such, of, by, the, shared, carriacou, patched,
# Nearest to their: only, were, than, groups, stop, golfers, leave, strongly,
# Nearest to than: higher, less, suppressive, much, their, more, not, governorate,
# Nearest to award: awards, nominated, awarded, terrence, short, recipients, ungulate, topped,
# Nearest to woman: gender, birth, expectancy, tiptree, lawfully, attends, total, dirt,
# Nearest to orthodox: isidore, cosa, parties, ques, dogmatic, pali, orthodoxy, transnistria,
# Nearest to report: downloadable, telling, spark, concluded, overpopulation, luke, tenders, suspects,
# Nearest to running: hominids, reheating, upset, jodi, suckling, iditarod, pero, marat,
# Nearest to writers: journalists, essayists, novelists, fiction, gogol, quine, othello, poe,
# Nearest to additional: introduction, nahin, prominently, alioth, helpers, mccormick, sands, waiver,
# Nearest to test: tests, florida, erich, closed, ephemerides, lyn, tropical, lond,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8677 0.0737 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8440 0.0667 sec/batch

# %% [markdown]
# ## 报错
# ValueError: invalid literal for int() with base 10: 'handle'
#
# debug: 是不是哪个类型有问题?
# 又一个地方传入的应该是int, 但是我传入了一个string, 所以出现问题.
#
# 错误出现在使用的train data, 使用了文字.

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
